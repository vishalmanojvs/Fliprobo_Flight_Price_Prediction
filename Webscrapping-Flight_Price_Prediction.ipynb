# %% [markdown]
# # Problem Statement

# %% [raw]
# # Calculating the MSE, RMSE and MAE for K-NN model
# mse=mean_absolute_error(y_test, predtest)
# rmse=np.sqrt(mse)
# print('The MAE is', mean_absolute_error(y_test, predtest))
# print ('The MSE is', mse, 'and RMSE is', rmse)FLIGHT PRICE PREDICTION Anyone who has booked a flight ticket knows how unexpectedly the prices vary. The cheapest available ticket on a given flight gets more and less expensive over time. This usually happens as an attempt to maximize revenue based on -
# 1. Time of purchase patterns (making sure last-minute purchases are expensive)
# 2. Keeping the flight as full as they want it (raising prices on a flight which is filling up in order to reduce sales and hold back inventory for those expensive last-minute expensive purchases) So, you have to work on a project where you collect data of flight fares with other features and work to make a model to predict fares of flights.
# 1. Data Collection
# You have to scrape at least 1500 rows of data. You can scrape more data as well, it’s up to you, More the data better the model
# In this section you have to scrape the data of flights from different websites (yatra.com, skyscanner.com, official websites of airlines, etc). The number of columns for data doesn’t have limit, it’s up to you and your creativity. Generally, these columns are airline name, date of journey, source, destination, route, departure time, arrival time, duration, total stops and the target variable price. You can make changes to it, you can add or you can remove some columns, it completely depends on the website from which you are fetching the data.
# 2. Data Analysis
# After cleaning the data, you have to do some analysis on the data. Do airfares change frequently? Do they move in small increments or in large jumps? Do they tend to go up or down over time? What is the best time to buy so that the consumer can save the most by taking the least risk? Does price increase as we get near to departure date? Is Indigo cheaper than Jet Airways? Are morning flights expensive?
# 3. Model Building
# After collecting the data, you need to build a machine learning model. Before model building do all data pre-processing steps. Try different models with different hyper parameters and select the best model.
# Follow the complete life cycle of data science. Include all the steps like
# 1. Data Cleaning
# 2. Exploratory Data Analysis
# 3. Data Pre-processing
# 4. Model Building
# 5. Model Evaluation
# 6. Selecting the best model

# %%
# Importing librabries
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
import requests
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Desktop\Important\pythondata\Sim\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://www.yatra.com/'
driver.get(url)

# %%
sd=driver.find_element(By.XPATH,'/html/body/div[2]/div/section/div[2]/div[2]/div/div/div/div[1]/div/a[2]')

# %%
sd.click()

# %%
sc=driver.find_element(By.XPATH,'/html/body/div[3]/div[2]/div/div[1]/div/div/div[3]/ul/li[6]/input')

# %%
sc.click()

# %%
d=driver.find_elements(By.XPATH,'//span[@class="text i-b"]')

# %%
len(d)
# Out:
# 7

# %%
n=[]
for i in range(0,7):
    n.append(d[i].text)

# %%
n
# Out:
# ['TAP Air Portugal',
#  'TAP Air Portugal',
#  'TAP Air Portugal',
#  'TAP Air Portugal',
#  'TAP Air Portugal',
#  'Air India',
#  'TAP Air Portugal']

# %%
s=driver.find_elements(By.XPATH,'//p[@class="i-b"]')

# %%
s[0].text
# Out:
# '58,201'

# %%
r=[]
for i in range(0,7):
    r.append(s[i].text)

# %%
r
# Out:
# ['58,201', '61,020', '61,414', '64,768', '64,794', '65,079', '65,188']

# %%
so=['New Delhi']

# %%
sour=so*10

# %%
de=['Toronto']

# %%
des=de*10

# %%
h=driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')

# %%
h[9].text
# Out:
# '49h 05m'

# %%
len(h)
# Out:
# 10

# %%
ho=[]
for i in range(0,10):
    ho.append(h[i].text)

# %%
n[2]='TAP Air Portugal'

# %%
n.insert(2,'TAP Air Portugal')

# %%
n.insert(3,'TAP Air Portugal')

# %%
n.insert(4,'TAP Air Portugal')

# %%
len(n)
# Out:
# 10

# %%
r.insert(1,'61,020')

# %%
r.insert(4,'64,768')

# %%
r.insert(5,'64,768')

# %%
len(r)
# Out:
# 10

# %%
s=driver.find_elements(By.XPATH,'//span[@class="dotted-borderbtm"]')

# %%
s[9].text
# Out:
# '2 Stops'

# %%
len(s)
# Out:
# 10

# %%
so=[]
for i in range(0,10):
    so.append(s[i].text)

# %%
so
# Out:
# ['2 Stops',
#  '2 Stops',
#  '2 Stops',
#  '2 Stops',
#  '2 Stops',
#  '2 Stops',
#  '2 Stops',
#  '2 Stops',
#  '1 Stop',
#  '2 Stops']

# %%
da=['18 Sept 22']

# %%
date=da*10

# %%
date
# Out:
# ['18 Sept 22',
#  '18 Sept 22',
#  '18 Sept 22',
#  '18 Sept 22',
#  '18 Sept 22',
#  '18 Sept 22',
#  '18 Sept 22',
#  '18 Sept 22',
#  '18 Sept 22',
#  '18 Sept 22']

# %%
f=pd.DataFrame(list(zip(n,date,sour,des,so,ho,r)),
               columns =['Name', 'Date','Source','Destination','Stops','Hours','Cost'])

# %%
f
# Out:
#                Name        Date     Source Destination    Stops    Hours  \
# 0  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  66h 00m
# 1  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
# 2  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
# 3  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
# 4  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 5  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 6  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 7  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 8         Air India  18 Sept 22  New Delhi     Toronto   1 Stop  30h 14m
# 9  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
#
#      Cost
# 0  58,201
# 1  61,020
# 2  61,020
# 3  61,414
# 4  64,768
# 5  64,768
# 6  64,768
# 7  64,794
# 8  65,079
# 9  65,188

# %%
f['Route']='DEL to LON to LIS'

# %%
f
# Out:
#                Name        Date     Source Destination    Stops    Hours  \
# 0  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  66h 00m
# 1  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
# 2  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
# 3  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
# 4  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 5  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 6  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 7  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 8         Air India  18 Sept 22  New Delhi     Toronto   1 Stop  30h 14m
# 9  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
#
#      Cost              Route
# 0  58,201  DEL to LON to LIS
# 1  61,020  DEL to LON to LIS
# 2  61,020  DEL to LON to LIS
# 3  61,414  DEL to LON to LIS
# ...

# %%
f['Route'][8]='DEL to LIS'

# %%
f
# Out:
#                Name        Date     Source Destination    Stops    Hours  \
# 0  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  66h 00m
# 1  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
# 2  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
# 3  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
# 4  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 5  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 6  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 7  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 8         Air India  18 Sept 22  New Delhi     Toronto   1 Stop  30h 14m
# 9  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
#
#      Cost              Route
# 0  58,201  DEL to LON to LIS
# 1  61,020  DEL to LON to LIS
# 2  61,020  DEL to LON to LIS
# 3  61,414  DEL to LON to LIS
# ...

# %%
f.to_csv('Set1',index= False)

# %%
# Connecting to the webpage
url= 'https://www.makemytrip.com/'
driver.get(url)

# %%
x=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[2]/div/div/div[2]/div[1]/div[1]/div[1]/div/div/div/input')

# %%
x.send_keys('Bangalore')

# %%
n=driver.find_elements(By.XPATH,'/html/body/div[1]/div/div[2]/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div[1]/input')

# %%
x.send_keys('Paris')

# %%
b=driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')

# %%
len(b)
# Out:
# 48

# %%
name=[]
for i in range(0,len(b)):
    name.append(b[i].text)

# %%
name
# Out:
# ['Srilankan Airlines',
#  'Gulf Air',
#  'Vistara, Air France',
#  'Vistara, Air France',
#  'Vistara, Air France',
#  'Vistara, Air France',
#  'Vistara, Air France',
#  'Vistara, Air France',
#  'Vistara, Air France',
#  'Vistara, Air France',
#  'Vistara, Air France',
#  'Vistara, Air France',
#  'Vistara, Air France',
#  'Etihad Airways',
#  'Air India',
#  'Air France',
#  'Vistara, Air France',
#  'Qatar Airways',
#  'Emirates',
#  'Emirates',
#  'Emirates',
#  'Emirates',
#  'Qatar Airways',
#  'Gulf Air',
#  'Qatar Airways',
#  'Emirates',
#  'Emirates',
#  'Emirates',
#  'Emirates',
#  'Qatar Airways',
#  'Gulf Air',
#  'Qatar Airways',
#  'Qatar Airways',
#  'Qatar Airways',
#  'Qatar Airways',
#  'Turkish Airlines',
#  'Turkish Airlines',
#  'Turkish Airlines',
#  'Lufthansa',
#  'Vistara, Air France',
#  'Vistara, Air France',
#  'Vistara, Air France',
#  'Lufthansa',
#  'Qatar Airways',
#  'Emirates',
#  'Emirates',
#  'Qatar Airways',
#  'Vistara, Emirates']

# %%
s=driver.find_elements(By.XPATH,'//p[@class="flightsLayoverInfo"]')

# %%
stop=[]
for i in range(0,len(b)):
    stop.append(s[i].text[:6])

# %%
stop
# Out:
# ['1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  'Non st',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '2 stop']

# %%
z=driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')

# %%
Hours=[]
for i in range(0,len(b)):
    Hours.append(z[i].text.split('\n')[0])

# %%
Hours
# Out:
# ['33 h 30 m',
#  '31 h 30 m',
#  '15 h',
#  '15 h 55 m',
#  '16 h 40 m',
#  '17 h 55 m',
#  '18 h 45 m',
#  '20 h 10 m',
#  '21 h 20 m',
#  '22 h 55 m',
#  '24 h',
#  '25 h 20 m',
#  '26 h 10 m',
#  '30 h 30 m',
#  '09 h 10 m',
#  '13 h 45 m',
#  '14 h 10 m',
#  '13 h 50 m',
#  '15 h 05 m',
#  '19 h 15 m',
#  '25 h 40 m',
#  '32 h 40 m',
#  '30 h 50 m',
#  '30 h 30 m',
#  '26 h 25 m',
#  '31 h 15 m',
#  '12 h 30 m',
#  '20 h 40 m',
#  '25 h 55 m',
#  '21 h',
#  '13 h 35 m',
#  '13 h 15 m',
#  '19 h 25 m',
#  '20 h 15 m',
#  '24 h 20 m',
#  '14 h 10 m',
#  '15 h 40 m',
#  '19 h 10 m',
#  '12 h 50 m',
#  '15 h 45 m',
#  '18 h 15 m',
#  '22 h 05 m',
#  '22 h 25 m',
#  '12 h 55 m',
#  '19 h 10 m',
#  '30 h',
#  '30 h 45 m',
#  '20 h']

# %%
d=driver.find_elements(By.XPATH,'//p[@class="blackText"]')

# %%
Source=[]
Destination=[]
for i in range(0,len(b)):
    if(i%2==0):
        Source.append(d[i].text)
    else:
        Destination.append(d[i].text)

# %%
Source
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi']

# %%
date=['29 Sept 22']*20

# %%
r=driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')

# %%
rate=[]
for i in range(0,len(b)):
    rate.append(r[i].text.split()[1])

# %%
r[0].text.split()[1]
# Out:
# '27,264'

# %%
p=pd.DataFrame(list(zip(name,date,Source,Destination,stop,Hours,rate)),
               columns =['Name', 'Date','Source','Destination','Stops','Hours','Cost'])

# %%
p
# Out:
#                    Name        Date     Source Destination   Stops      Hours  \
# 0    Srilankan Airlines  29 Sept 22  New Delhi       Paris  1 stop  33 h 30 m
# 1              Gulf Air  29 Sept 22  New Delhi       Paris  1 stop  31 h 30 m
# 2   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop       15 h
# 3   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  15 h 55 m
# 4   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  16 h 40 m
# 5   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  17 h 55 m
# 6   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  18 h 45 m
# 7   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  20 h 10 m
# 8   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  21 h 20 m
# 9   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  22 h 55 m
# 10  Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop       24 h
# ...

# %%
re=[]
for i in range(0,len(b)):
    re.append(s[i].text.split()[-1])

# %%
p['Route1']=re[:20]

# %%
p
# Out:
#                    Name        Date     Source Destination   Stops      Hours  \
# 0    Srilankan Airlines  29 Sept 22  New Delhi       Paris  1 stop  33 h 30 m
# 1              Gulf Air  29 Sept 22  New Delhi       Paris  1 stop  31 h 30 m
# 2   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop       15 h
# 3   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  15 h 55 m
# 4   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  16 h 40 m
# 5   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  17 h 55 m
# 6   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  18 h 45 m
# 7   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  20 h 10 m
# 8   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  21 h 20 m
# 9   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  22 h 55 m
# 10  Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop       24 h
# ...

# %%
sr={'Colombo': 'DEL to RML to CDG','Bahrain':'DEL to BAH to CDG','Mumbai':'DEL to BOM to CDG','Dhabi':'DEL to AUH to CDG','Doha':'DEL to DIA to CDG','Dubai':'DEL to DXB to CDG', 'stop':'DEL to CDG'}

# %%
p['Route']=p['Route1'].map(sr)

# %%
p
# Out:
#                    Name        Date     Source Destination   Stops      Hours  \
# 0    Srilankan Airlines  29 Sept 22  New Delhi       Paris  1 stop  33 h 30 m
# 1              Gulf Air  29 Sept 22  New Delhi       Paris  1 stop  31 h 30 m
# 2   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop       15 h
# 3   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  15 h 55 m
# 4   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  16 h 40 m
# 5   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  17 h 55 m
# 6   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  18 h 45 m
# 7   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  20 h 10 m
# 8   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  21 h 20 m
# 9   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  22 h 55 m
# 10  Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop       24 h
# ...

# %%
p.drop('Route1',axis=1, inplace=True)

# %%
p
# Out:
#                    Name        Date     Source Destination   Stops      Hours  \
# 0    Srilankan Airlines  29 Sept 22  New Delhi       Paris  1 stop  33 h 30 m
# 1              Gulf Air  29 Sept 22  New Delhi       Paris  1 stop  31 h 30 m
# 2   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop       15 h
# 3   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  15 h 55 m
# 4   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  16 h 40 m
# 5   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  17 h 55 m
# 6   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  18 h 45 m
# 7   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  20 h 10 m
# 8   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  21 h 20 m
# 9   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  22 h 55 m
# 10  Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop       24 h
# ...

# %%
p.to_csv('Set2',index= False)

# %%
# Connecting to the webpage
url= 'https://www.makemytrip.com/'
driver.get(url)

# %%
n=driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')

# %%
len(n)
# Out:
# 136

# %%
name=[]
for i in range(0,len(n)):
    name.append(n[i].text)

# %%
name
# Out:
# ['Vistara, United Airlines',
#  'United Airlines',
#  'Lufthansa',
#  'Qatar Airways, Air Canada',
#  'Qatar Airways, American Airlines',
#  'Emirates, WestJet',
#  'Etihad Airways',
#  'Srilankan Airlines',
#  'Delta Air Lines',
#  'Air France',
#  'British Airways, Air Canada',
#  'British Airways, Air Canada',
#  'British Airways, Air Canada',
#  'Qatar Airways, Air Canada',
#  'Qatar Airways, Porter Airlines',
#  'Qatar Airways, Air Canada',
#  'Qatar Airways, WestJet',
#  'Qatar Airways, Air Canada',
#  'Qatar Airways, Air Canada',
#  'Qatar Airways, Air Canada',
#  'Qatar Airways, Air Canada',
#  'Air Canada',
#  'Vistara, United Airlines',
#  'Vistara, United Airlines',
#  'Qatar Airways, Air Canada',
#  'British Airways',
#  'Delta Air Lines',
#  'Delta Air Lines',
#  'Delta Air Lines, WestJet',
#  'Lufthansa',
#  'Lufthansa',
#  'Qatar Airways, Air Canada',
#  'Qatar Airways, Air Canada',
#  'Qatar Airways, Porter Airlines',
#  'Qatar Airways, Air Canada',
# ...

# %%
s=driver.find_elements(By.XPATH,'//p[@class="flightsLayoverInfo"]')

# %%
re=[]
for i in range(0,len(n)):
    re.append(s[i].text[11:])
stop=[]
for i in range(0,len(n)):
    stop.append(s[i].text[:6])

# %%
len(re)
# Out:
# 136

# %%
len(stop)
# Out:
# 136

# %%
len(s)
# Out:
# 136

# %%
s[135].text[11:]
# Out:
# 'Abu Dhabi,London - Heathrow Apt'

# %%
d=driver.find_elements(By.XPATH,'//p[@class="blackText"]')

# %%
Source=[]
Destination=[]
for i in range(0,len(d)):
    if(i%2==0):
        Source.append(d[i].text)
    else:
        Destination.append(d[i].text)

# %%
len(Source)
# Out:
# 136

# %%
z=driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')

# %%
Hours=[]
for i in range(0,len(n)):
    Hours.append(z[i].text.split('\n')[0])

# %%
c=driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')

# %%
cost=[]
for i in range(0,len(n)):
    cost.append(c[i].text.split()[1])

# %%
date=['29 Oct 22']*136

# %%
i=pd.DataFrame(list(zip(name,date,Source,Destination,stop,Hours,cost,re)),
               columns =['Name', 'Date','Source','Destination','Stops','Hours','Cost','Route'])

# %%
i
# Out:
#                                  Name       Date     Source Destination  \
# 0            Vistara, United Airlines  29 Oct 22  Bengaluru     Toronto
# 1                     United Airlines  29 Oct 22  Bengaluru     Toronto
# 2                           Lufthansa  29 Oct 22  Bengaluru     Toronto
# 3           Qatar Airways, Air Canada  29 Oct 22  Bengaluru     Toronto
# 4    Qatar Airways, American Airlines  29 Oct 22  Bengaluru     Toronto
# ..                                ...        ...        ...         ...
# 131                   Delta Air Lines  29 Oct 22  Bengaluru     Toronto
# 132                   Delta Air Lines  29 Oct 22  Bengaluru     Toronto
# 133                         Lufthansa  29 Oct 22  Bengaluru     Toronto
# 134           Etihad Airways, Finnair  29 Oct 22  Bengaluru     Toronto
# 135           Etihad Airways, Finnair  29 Oct 22  Bengaluru     Toronto
#
#       Stops      Hours      Cost                            Route
# ...

# %%
i['Route'].unique()
# Out:
# array(['New Delhi,Newark', 'New Delhi,Chicago', 'Frankfurt',
#        'Doha,New York', 'Doha,Philadelphia', 'Dubai,Boston', 'Abu Dhabi',
#        'Colombo,London - Heathrow Apt', 'Paris',
#        'London - Heathrow Apt,Montreal', 'Doha,Montreal',
#        'London - Heathrow Apt', 'Paris,Amsterdam', 'Paris,Boston',
#        'Frankfurt,Dublin', 'Doha', 'Dubai', 'Paris,Montreal',
#        'Mumbai,Amsterdam', 'New Delhi', 'Frankfurt,Munich',
#        'Paris,New York', 'Addis Ababa,Dublin', 'Mumbai,Zurich',
#        'New Delhi,Frankfurt', 'New Delhi,Munich',
#        'Frankfurt,London - Heathrow Apt', 'Dubai,London - Heathrow Apt',
#        'Frankfurt,Vancouver', 'Abu Dhabi,London - Heathrow Apt'],
#       dtype=object)

# %%
sr={'New Delhi,Newark':'BLR to DEL to EWR to LIS', 'New Delhi,Chicago':'BLR to DEL to ORD to LIS', 'Frankfurt':'BLR to FRA to LIS',
       'Doha,New York':'BLR to DIA to NYC to LIS', 'Doha,Philadelphia':'BLR to DIA to PHL to LIS', 'Dubai,Boston':'BLR to DXB to BOS to LIS', 'Abu Dhabi':'BLR to AUH to LIS',
       'Colombo,London - Heathrow Apt':'BLR to CMB to LHR to LIS', 'Paris':'BLR to CDG',
       'London - Heathrow Apt,Montreal':'BLR to LHR to YUL to LIS', 'Doha,Montreal':'BLR to DIA to YUL to LIS',
       'London - Heathrow Apt':'BLR to LHR to LIS', 'Paris,Amsterdam':'BLR to CDG to AMS to LIS', 'Paris,Boston':'BLR to CDG to BOS to LIS',
       'Frankfurt,Dublin':'BLR to FRA to DUB to LIS', 'Doha':'BLR to DIA to LIS', 'Dubai':'BLR to DXB to LIS', 'Paris,Montreal':'BLR to CDG to YUL to LIS',
       'Mumbai,Amsterdam':'BLR to BOM to AMS to LIS', 'New Delhi':'BLR to DEL to LIS', 'Frankfurt,Munich':'BLR to FRA to MUC to LIS',
       'Paris,New York':'BLR to CDG to NYC to LIS', 'Addis Ababa,Dublin':'BLR to ADD to DUB', 'Mumbai,Zurich':'BLR to BOM to ZRH to DUB',
       'New Delhi,Frankfurt':'BLR to DEL to FRA to LIS', 'New Delhi,Munich':'BLR to DEL to MUC to LIS',
       'Frankfurt,London - Heathrow Apt':'BLR to FRA to LHR to LIS', 'Dubai,London - Heathrow Apt':'BLR to DXB to LHR to LIS',
       'Frankfurt,Vancouver':'BLR to FRA to YVR to LIS', 'Abu Dhabi,London - Heathrow Apt':'BLR to AUH to LHR to LIS'}

# %%
i['Route']=i['Route'].map(sr)

# %%
i
# Out:
#                                  Name       Date     Source Destination  \
# 0            Vistara, United Airlines  29 Oct 22  Bengaluru     Toronto
# 1                     United Airlines  29 Oct 22  Bengaluru     Toronto
# 2                           Lufthansa  29 Oct 22  Bengaluru     Toronto
# 3           Qatar Airways, Air Canada  29 Oct 22  Bengaluru     Toronto
# 4    Qatar Airways, American Airlines  29 Oct 22  Bengaluru     Toronto
# ..                                ...        ...        ...         ...
# 131                   Delta Air Lines  29 Oct 22  Bengaluru     Toronto
# 132                   Delta Air Lines  29 Oct 22  Bengaluru     Toronto
# 133                         Lufthansa  29 Oct 22  Bengaluru     Toronto
# 134           Etihad Airways, Finnair  29 Oct 22  Bengaluru     Toronto
# 135           Etihad Airways, Finnair  29 Oct 22  Bengaluru     Toronto
#
#       Stops      Hours      Cost                     Route
# ...

# %%
i.to_csv('Set3',index= False)

# %%
n=driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')

# %%
name=[]
for i in range(0,len(n)):
    name.append(n[i].text)

# %%
len(name)
# Out:
# 143

# %%
s=driver.find_elements(By.XPATH,'//p[@class="flightsLayoverInfo"]')

# %%
re=[]
for i in range(0,len(n)):
    re.append(s[i].text[11:])
stop=[]
for i in range(0,len(n)):
    stop.append(s[i].text[:6])

# %%
d=driver.find_elements(By.XPATH,'//p[@class="blackText"]')

# %%
Source=[]
Destination=[]
for i in range(0,len(d)):
    if(i%2==0):
        Source.append(d[i].text)
    else:
        Destination.append(d[i].text)

# %%
z=driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')

# %%
Hours=[]
for i in range(0,len(n)):
    Hours.append(z[i].text.split('\n')[0])

# %%
c=driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')

# %%
cost=[]
for i in range(0,len(n)):
    cost.append(c[i].text.split()[1])

# %%
date=['27 Nov 22']*143

# %%
v=pd.DataFrame(list(zip(name,date,Source,Destination,stop,Hours,cost,re)),
               columns =['Name', 'Date','Source','Destination','Stops','Hours','Cost','Route'])

# %%
v
# Out:
#                                   Name       Date     Source Destination  \
# 0                  Vistara, Air France  27 Nov 22  New Delhi     Toronto
# 1                  Vistara, Air France  27 Nov 22  New Delhi     Toronto
# 2                  Vistara, Air France  27 Nov 22  New Delhi     Toronto
# 3                       Japan Airlines  27 Nov 22  New Delhi     Toronto
# 4    Japan Airlines, American Airlines  27 Nov 22  New Delhi     Toronto
# ..                                 ...        ...        ...         ...
# 138                    United Airlines  27 Nov 22  New Delhi     Toronto
# 139         British Airways, Lufthansa  27 Nov 22  New Delhi     Toronto
# 140                    Delta Air Lines  27 Nov 22  New Delhi     Toronto
# 141                 All Nippon Airways  27 Nov 22  New Delhi     Toronto
# 142                 All Nippon Airways  27 Nov 22  New Delhi     Toronto
#
#       Stops      Hours       Cost                          Route
# ...

# %%
v['Route'].unique()
# Out:
# array(['Bengaluru,Paris', 'Tokyo-Haneda Airport,Chicago',
#        'Tokyo-Haneda Airport,New York', 'Dubai,Orlando',
#        'Zurich,Montreal', 'Munich,Frankfurt', 'Frankfurt', 'Munich', '',
#        'Mumbai,Amsterdam', 'Dubai',
#        'Tokyo-Haneda Airport,Dallas/Fort Worth', 'London - Heathrow Apt',
#        'Abu Dhabi', 'Munich,Amsterdam', 'Munich,London - Heathrow Apt',
#        'Doha,Montreal', 'Amsterdam', 'Amsterdam,Minneapolis', 'Zurich',
#        'Munich,Vienna', 'Munich,Copenhagen', 'Munich,Zurich',
#        'Newark,Montreal', 'Frankfurt,London - Heathrow Apt',
#        'Mumbai,London - Heathrow Apt', 'Dubai,London - Gatwick Apt',
#        'Dubai,London - Stansted Apt', 'Seoul-Incheon',
#        'Munich,Rome - Fiumicino Apt', 'Frankfurt,Zurich',
#        'Frankfurt,Munich', 'Doha,Philadelphia', 'Zurich,Vienna',
#        'Frankfurt,Montreal', 'Newark', 'Chicago', 'New York',
#        'Paris,Montreal', 'Paris'], dtype=object)

# %%
sm={'Bengaluru,Paris':'DEL to BLR to CDG to LIS', 'Tokyo-Haneda Airport,Chicago':'DEL to HND to ORD to LIS',
       'Tokyo-Haneda Airport,New York':'DEL to HND to NYC to LIS', 'Dubai,Orlando':'DEL to DXB to MCO to LIS',
       'Zurich,Montreal':'DEL to ZRH to YUL to LIS', 'Munich,Frankfurt':'DEL to MUC to FRA to LIS', 'Frankfurt':'DEL to FRA to LIS', 'Munich':'DEL to MUC to LIS', '':'DEL to LIS',
       'Mumbai,Amsterdam':'DEL to BOM to AMS to DEL', 'Dubai':'DEL to DXB to LIS',
       'Tokyo-Haneda Airport,Dallas/Fort Worth':'DEL to HND to DFW to LIS', 'London - Heathrow Apt':'DEL to LHR to LIS',
       'Abu Dhabi':'DEL to AUH to LIS', 'Munich,Amsterdam':'DEL to MUC to AMS to LIS', 'Munich,London - Heathrow Apt':'DEL to MUC to LHR to LIS',
       'Doha,Montreal':'DEL to DIA to YUL to LIS', 'Amsterdam':'DEL to AMS to LIS', 'Amsterdam,Minneapolis':'DEL to AMS to MSP to LIS', 'Zurich':'DEL to ZRH to LIS',
       'Munich,Vienna':'DEL to MUC to VIE to LIS', 'Munich,Copenhagen':'DEL to MUC to CPH to LIS', 'Munich,Zurich':'DEL to MUC to ZRH to LIS',
       'Newark,Montreal':'DEL to EWR to YUL to LIS', 'Frankfurt,London - Heathrow Apt':'DEL to FRA to LHR to LIS',
       'Mumbai,London - Heathrow Apt':'DEL to BOM to LHR to LIS', 'Dubai,London - Gatwick Apt':'DEL to DXB to LGW to LIS',
       'Dubai,London - Stansted Apt':'DEL to DXB to STN to LIS', 'Seoul-Incheon':'DEL to ICN to LIS',
       'Munich,Rome - Fiumicino Apt':'DEL to MUC to FCO to LIS', 'Frankfurt,Zurich':'DEL to FRA to ZRH to LIS',
       'Frankfurt,Munich':'DEL to FRA to MUC to LIS', 'Doha,Philadelphia':'DEL to DIA to PHL to LIS', 'Zurich,Vienna':'DEL to ZRH to VIE to LIS',
       'Frankfurt,Montreal':'DEL to FRA to YUL to LIS', 'Newark':'DEL to EWR to LIS', 'Chicago':'DEL to ORD to LIS', 'New York':'DEL to NYU to LIS',
       'Paris,Montreal':'DEL to CDG to YUL to LIS', 'Paris':'DEL to CDG to LIS'}

# %%
v['Route']=v['Route'].map(sm)

# %%
v
# Out:
#                                   Name       Date     Source Destination  \
# 0                  Vistara, Air France  27 Nov 22  New Delhi     Toronto
# 1                  Vistara, Air France  27 Nov 22  New Delhi     Toronto
# 2                  Vistara, Air France  27 Nov 22  New Delhi     Toronto
# 3                       Japan Airlines  27 Nov 22  New Delhi     Toronto
# 4    Japan Airlines, American Airlines  27 Nov 22  New Delhi     Toronto
# ..                                 ...        ...        ...         ...
# 138                    United Airlines  27 Nov 22  New Delhi     Toronto
# 139         British Airways, Lufthansa  27 Nov 22  New Delhi     Toronto
# 140                    Delta Air Lines  27 Nov 22  New Delhi     Toronto
# 141                 All Nippon Airways  27 Nov 22  New Delhi     Toronto
# 142                 All Nippon Airways  27 Nov 22  New Delhi     Toronto
#
#       Stops      Hours       Cost                     Route
# ...

# %%
v.to_csv('Set4',index= False)

# %%
n=driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')

# %%
name=[]
for i in range(0,len(n)):
    name.append(n[i].text)

# %%
len(name)
# Out:
# 41

# %%
s=driver.find_elements(By.XPATH,'//p[@class="flightsLayoverInfo"]')

# %%
re=[]
for i in range(0,len(n)):
    re.append(s[i].text[11:])
stop=[]
for i in range(0,len(n)):
    stop.append(s[i].text[:6])

# %%
d=driver.find_elements(By.XPATH,'//p[@class="blackText"]')

# %%
Source=[]
Destination=[]
for i in range(0,len(d)):
    if(i%2==0):
        Source.append(d[i].text)
    else:
        Destination.append(d[i].text)

# %%
z=driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')

# %%
Hours=[]
for i in range(0,len(n)):
    Hours.append(z[i].text.split('\n')[0])

# %%
c=driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')

# %%
cost=[]
for i in range(0,len(n)):
    cost.append(c[i].text.split()[1])

# %%
date=['30 Nov 22']*41

# %%
mv=pd.DataFrame(list(zip(name,date,Source,Destination,stop,Hours,cost,re)),
               columns =['Name', 'Date','Source','Destination','Stops','Hours','Cost','Route'])

# %%
mv
# Out:
#          Name       Date     Source Destination   Stops      Hours   Cost  \
# 0    Go First  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,366
# 1    Go First  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,368
# 2   Akasa Air  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,371
# 3    SpiceJet  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,680
# 4     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,682
# 5     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,682
# 6     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,682
# 7     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 55 m  7,682
# 8     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,682
# 9      IndiGo  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,684
# 10     IndiGo  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,684
# 11  Air India  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,684
# ...

# %%
mv['Route'].unique()
# Out:
# array(['', 'Pune', 'Mumbai'], dtype=object)

# %%
sd={'':'BLR to DEL', 'Pune':'BLR to PNQ to DEL', 'Mumbai':'BLR to BOM to DEL'}

# %%
mv['Route']=mv['Route'].map(sd)

# %%
mv.to_csv('Set5',index= False)

# %%
mv
# Out:
#          Name       Date     Source Destination   Stops      Hours   Cost  \
# 0    Go First  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,366
# 1    Go First  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,368
# 2   Akasa Air  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,371
# 3    SpiceJet  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,680
# 4     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,682
# 5     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,682
# 6     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,682
# 7     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 55 m  7,682
# 8     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,682
# 9      IndiGo  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,684
# 10     IndiGo  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,684
# 11  Air India  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,684
# ...

# %%
n=driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')

# %%
name=[]
for i in range(0,len(n)):
    name.append(n[i].text)

# %%
len(name)
# Out:
# 37

# %%
s=driver.find_elements(By.XPATH,'//p[@class="flightsLayoverInfo"]')

# %%
re=[]
for i in range(0,len(n)):
    re.append(s[i].text[11:])
stop=[]
for i in range(0,len(n)):
    stop.append(s[i].text[:6])

# %%
d=driver.find_elements(By.XPATH,'//p[@class="blackText"]')

# %%
Source=[]
Destination=[]
for i in range(0,len(d)):
    if(i%2==0):
        Source.append(d[i].text)
    else:
        Destination.append(d[i].text)

# %%
z=driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')

# %%
Hours=[]
for i in range(0,len(n)):
    Hours.append(z[i].text.split('\n')[0])

# %%
c=driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')

# %%
cost=[]
for i in range(0,len(n)):
    cost.append(c[i].text.split()[1])

# %%
date=['21 sep 22']*37

# %%
m=pd.DataFrame(list(zip(name,date,Source,Destination,stop,Hours,cost,re)),
               columns =['Name', 'Date','Source','Destination','Stops','Hours','Cost','Route'])

# %%
m
# Out:
#          Name       Date     Source Destination   Stops      Hours    Cost  \
# 0    Go First  21 sep 22  Bengaluru   New Delhi  Non st  02 h 40 m   7,682
# 1    SpiceJet  21 sep 22  Bengaluru   New Delhi  Non st  02 h 35 m   7,682
# 2    Go First  21 sep 22  Bengaluru   New Delhi  Non st  02 h 45 m   7,682
# 3      IndiGo  21 sep 22  Bengaluru   New Delhi  Non st  02 h 45 m   7,684
# 4   Air India  21 sep 22  Bengaluru   New Delhi  Non st  02 h 50 m   7,684
# 5   Air India  21 sep 22  Bengaluru   New Delhi  Non st  02 h 50 m   7,684
# 6   Air India  21 sep 22  Bengaluru   New Delhi  Non st  02 h 45 m   7,684
# 7      IndiGo  21 sep 22  Bengaluru   New Delhi  Non st  02 h 50 m   7,684
# 8      IndiGo  21 sep 22  Bengaluru   New Delhi  Non st  02 h 55 m   7,684
# 9   Air India  21 sep 22  Bengaluru   New Delhi  Non st  02 h 50 m   7,684
# 10     IndiGo  21 sep 22  Bengaluru   New Delhi  Non st  02 h 45 m   7,684
# ...

# %%
m['Route'].unique()
# Out:
# array(['', 'Mumbai', 'Pune', 'Goa', 'Hyderabad', 'Indore'], dtype=object)

# %%
sd={'':'BLR to DEL', 'Pune':'BLR to PNQ to DEL', 'Mumbai':'BLR to BOM to DEL','Goa':'BLR to GOI to DEL','Hyderabad':'BLR to HYD to DEL', 'Indore':'BLR to IDR to DEL'}

# %%
m['Route']=m['Route'].map(sd)

# %%
m
# Out:
#          Name       Date     Source Destination   Stops      Hours    Cost  \
# 0    Go First  21 sep 22  Bengaluru   New Delhi  Non st  02 h 40 m   7,682
# 1    SpiceJet  21 sep 22  Bengaluru   New Delhi  Non st  02 h 35 m   7,682
# 2    Go First  21 sep 22  Bengaluru   New Delhi  Non st  02 h 45 m   7,682
# 3      IndiGo  21 sep 22  Bengaluru   New Delhi  Non st  02 h 45 m   7,684
# 4   Air India  21 sep 22  Bengaluru   New Delhi  Non st  02 h 50 m   7,684
# 5   Air India  21 sep 22  Bengaluru   New Delhi  Non st  02 h 50 m   7,684
# 6   Air India  21 sep 22  Bengaluru   New Delhi  Non st  02 h 45 m   7,684
# 7      IndiGo  21 sep 22  Bengaluru   New Delhi  Non st  02 h 50 m   7,684
# 8      IndiGo  21 sep 22  Bengaluru   New Delhi  Non st  02 h 55 m   7,684
# 9   Air India  21 sep 22  Bengaluru   New Delhi  Non st  02 h 50 m   7,684
# 10     IndiGo  21 sep 22  Bengaluru   New Delhi  Non st  02 h 45 m   7,684
# ...

# %%
m.to_csv('Set6',index= False)

# %%
n=driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')

# %%
name=[]
for i in range(0,len(n)):
    name.append(n[i].text)

# %%
len(name)
# Out:
# 128

# %%
s=driver.find_elements(By.XPATH,'//p[@class="flightsLayoverInfo"]')

# %%
re=[]
for i in range(0,len(n)):
    re.append(s[i].text[11:])
stop=[]
for i in range(0,len(n)):
    stop.append(s[i].text[:6])

# %%
d=driver.find_elements(By.XPATH,'//p[@class="blackText"]')

# %%
Source=[]
Destination=[]
for i in range(0,len(d)):
    if(i%2==0):
        Source.append(d[i].text)
    else:
        Destination.append(d[i].text)

# %%
z=driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')

# %%
Hours=[]
for i in range(0,len(n)):
    Hours.append(z[i].text.split('\n')[0])

# %%
c=driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')

# %%
cost=[]
for i in range(0,len(n)):
    cost.append(c[i].text.split()[-1])

# %%
c[0].text.split()[-1]
# Out:
# '38,192'

# %%
date=['28 Oct 22']*128

# %%
a=pd.DataFrame(list(zip(name,date,Source,Destination,stop,Hours,cost,re)),
               columns =['Name', 'Date','Source','Destination','Stops','Hours','Cost','Route'])

# %%
a
# Out:
#                             Name       Date     Source           Destination  \
# 0                  Qatar Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 1                 Etihad Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 2                  Qatar Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 3                  Qatar Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 4                       Gulf Air  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# ..                           ...        ...        ...                   ...
# 123    Air France, Kenya Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 124      Vistara, Etihad Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 125         Air France, Alitalia  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 126  Vistara, Singapore Airlines  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 127  Vistara, Singapore Airlines  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
#
# ...

# %%
a['Route'].unique()
# Out:
# array(['Doha', 'Abu Dhabi', 'Bahrain', 'Frankfurt', 'Mumbai,Istanbul',
#        'Amsterdam', 'Dubai', 'Paris', 'Frankfurt,Munich', 'Singapore',
#        'Amsterdam,Paris', 'Mumbai,Doha', 'Mumbai,Dubai',
#        'Mumbai,Amsterdam', 'Frankfurt,Milan',
#        'Frankfurt,Milan-Linate Airport', 'Paris,Amsterdam',
#        'London - Heathrow Apt', 'Mumbai,Munich', 'Frankfurt,Florence',
#        'New Delhi,Frankfurt', 'Frankfurt,Venice', 'New Delhi,Dubai',
#        'New Delhi,Paris', 'Amsterdam,Milan-Linate Airport',
#        'New Delhi,Zurich', 'Mumbai,Abu Dhabi',
#        'Paris,Milan-Linate Airport', 'Mumbai,Singapore'], dtype=object)

# %%
se={'Doha':'BLR to DIA to FCO', 'Abu Dhabi':'BLR to AUH to FCO', 'Bahrain':'BLR to BAH to FCO', 'Frankfurt':'BLR to FRA to FCO', 'Mumbai,Istanbul':'BLR to BOM to IST to FCO',
       'Amsterdam':'BLR to AMS to FCO', 'Dubai':'BLR to DXB to FCO', 'Paris':'BLR to CDG to FCO', 'Frankfurt,Munich':'BLR to FRA to MUC to FCO', 'Singapore':'BLR to SIN to FCO',
       'Amsterdam,Paris':'BLR to AMS to CDG to FCO', 'Mumbai,Doha':'BLR to BOM to DIA to FCO', 'Mumbai,Dubai':'BLR to BOM to DXB to FCO',
       'Mumbai,Amsterdam':'BLR to BOM to AMS to FCO', 'Frankfurt,Milan':'BLR to FRA to LIN to FCO',
       'Frankfurt,Milan-Linate Airport':'BLR to FRA to LIN to FCO', 'Paris,Amsterdam':'BLR to CDG to AMS to FCO',
       'London - Heathrow Apt':'BLR to LHR to FCO', 'Mumbai,Munich':'BLR to BOM to MUC to FCO', 'Frankfurt,Florence':'BLR to FRA to FLR to FCO',
       'New Delhi,Frankfurt':'BLR to DEL to FRA to FCO', 'Frankfurt,Venice':'BLR to FRA to VCE to FCO', 'New Delhi,Dubai':'BLR to DEL to DXB to FCO',
       'New Delhi,Paris':'BLR to DEL to CDG to FCO', 'Amsterdam,Milan-Linate Airport':'BLR to AMS to LIN to FCO',
       'New Delhi,Zurich':'BLR to DEL to ZRH to FCO', 'Mumbai,Abu Dhabi':'BLR to BOM to AUH to FCO',
       'Paris,Milan-Linate Airport':'BLR to CDG to LIN to FCO', 'Mumbai,Singapore':'BLR to BOM to SIN to FCO'}

# %%
a['Route']=a['Route'].map(se)

# %%
a.to_csv('Set7',index= False)

# %%
a
# Out:
#                             Name       Date     Source           Destination  \
# 0                  Qatar Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 1                 Etihad Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 2                  Qatar Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 3                  Qatar Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 4                       Gulf Air  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# ..                           ...        ...        ...                   ...
# 123    Air France, Kenya Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 124      Vistara, Etihad Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 125         Air France, Alitalia  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 126  Vistara, Singapore Airlines  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 127  Vistara, Singapore Airlines  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
#
# ...

# %%
import pandas as pd

# %%
a=pd.read_csv('Set1')

# %%
a
# Out:
#                Name        Date     Source Destination    Stops    Hours  \
# 0  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  66h 00m
# 1  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
# 2  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
# 3  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
# 4  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 5  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 6  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 7  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  42h 00m
# 8         Air India  18 Sept 22  New Delhi     Toronto   1 Stop  30h 14m
# 9  TAP Air Portugal  18 Sept 22  New Delhi     Toronto  2 Stops  49h 05m
#
#      Cost              Route
# 0  58,201  DEL to LON to LIS
# 1  61,020  DEL to LON to LIS
# 2  61,020  DEL to LON to LIS
# 3  61,414  DEL to LON to LIS
# ...

# %%
z=pd.read_csv('Set2')

# %%
z
# Out:
#                    Name        Date     Source Destination   Stops      Hours  \
# 0    Srilankan Airlines  29 Sept 22  New Delhi       Paris  1 stop  33 h 30 m
# 1              Gulf Air  29 Sept 22  New Delhi       Paris  1 stop  31 h 30 m
# 2   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop       15 h
# 3   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  15 h 55 m
# 4   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  16 h 40 m
# 5   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  17 h 55 m
# 6   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  18 h 45 m
# 7   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  20 h 10 m
# 8   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  21 h 20 m
# 9   Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop  22 h 55 m
# 10  Vistara, Air France  29 Sept 22  New Delhi       Paris  1 stop       24 h
# ...

# %%
n=pd.read_csv('Set3')

# %%
n
# Out:
#                                  Name       Date     Source Destination  \
# 0            Vistara, United Airlines  29 Oct 22  Bengaluru     Toronto
# 1                     United Airlines  29 Oct 22  Bengaluru     Toronto
# 2                           Lufthansa  29 Oct 22  Bengaluru     Toronto
# 3           Qatar Airways, Air Canada  29 Oct 22  Bengaluru     Toronto
# 4    Qatar Airways, American Airlines  29 Oct 22  Bengaluru     Toronto
# ..                                ...        ...        ...         ...
# 131                   Delta Air Lines  29 Oct 22  Bengaluru     Toronto
# 132                   Delta Air Lines  29 Oct 22  Bengaluru     Toronto
# 133                         Lufthansa  29 Oct 22  Bengaluru     Toronto
# 134           Etihad Airways, Finnair  29 Oct 22  Bengaluru     Toronto
# 135           Etihad Airways, Finnair  29 Oct 22  Bengaluru     Toronto
#
#       Stops      Hours      Cost                     Route
# ...

# %%
w=pd.read_csv('Set4')

# %%
w
# Out:
#                                   Name       Date     Source Destination  \
# 0                  Vistara, Air France  27 Nov 22  New Delhi     Toronto
# 1                  Vistara, Air France  27 Nov 22  New Delhi     Toronto
# 2                  Vistara, Air France  27 Nov 22  New Delhi     Toronto
# 3                       Japan Airlines  27 Nov 22  New Delhi     Toronto
# 4    Japan Airlines, American Airlines  27 Nov 22  New Delhi     Toronto
# ..                                 ...        ...        ...         ...
# 138                    United Airlines  27 Nov 22  New Delhi     Toronto
# 139         British Airways, Lufthansa  27 Nov 22  New Delhi     Toronto
# 140                    Delta Air Lines  27 Nov 22  New Delhi     Toronto
# 141                 All Nippon Airways  27 Nov 22  New Delhi     Toronto
# 142                 All Nippon Airways  27 Nov 22  New Delhi     Toronto
#
#       Stops      Hours       Cost                     Route
# ...

# %%
s=pd.read_csv('Set5')

# %%
s
# Out:
#          Name       Date     Source Destination   Stops      Hours   Cost  \
# 0    Go First  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,366
# 1    Go First  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,368
# 2   Akasa Air  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,371
# 3    SpiceJet  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,680
# 4     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,682
# 5     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,682
# 6     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,682
# 7     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 55 m  7,682
# 8     AirAsia  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,682
# 9      IndiGo  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 50 m  7,684
# 10     IndiGo  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,684
# 11  Air India  30 Nov 22  Bengaluru   New Delhi  Non st  02 h 45 m  7,684
# ...

# %%
u=pd.read_csv('Set6')

# %%
u
# Out:
#          Name       Date     Source Destination   Stops      Hours    Cost  \
# 0    Go First  21 sep 22  Bengaluru   New Delhi  Non st  02 h 40 m   7,682
# 1    SpiceJet  21 sep 22  Bengaluru   New Delhi  Non st  02 h 35 m   7,682
# 2    Go First  21 sep 22  Bengaluru   New Delhi  Non st  02 h 45 m   7,682
# 3      IndiGo  21 sep 22  Bengaluru   New Delhi  Non st  02 h 45 m   7,684
# 4   Air India  21 sep 22  Bengaluru   New Delhi  Non st  02 h 50 m   7,684
# 5   Air India  21 sep 22  Bengaluru   New Delhi  Non st  02 h 50 m   7,684
# 6   Air India  21 sep 22  Bengaluru   New Delhi  Non st  02 h 45 m   7,684
# 7      IndiGo  21 sep 22  Bengaluru   New Delhi  Non st  02 h 50 m   7,684
# 8      IndiGo  21 sep 22  Bengaluru   New Delhi  Non st  02 h 55 m   7,684
# 9   Air India  21 sep 22  Bengaluru   New Delhi  Non st  02 h 50 m   7,684
# 10     IndiGo  21 sep 22  Bengaluru   New Delhi  Non st  02 h 45 m   7,684
# ...

# %%
o=pd.read_csv('Set7')

# %%
o
# Out:
#                             Name       Date     Source           Destination  \
# 0                  Qatar Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 1                 Etihad Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 2                  Qatar Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 3                  Qatar Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 4                       Gulf Air  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# ..                           ...        ...        ...                   ...
# 123    Air France, Kenya Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 124      Vistara, Etihad Airways  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 125         Air France, Alitalia  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 126  Vistara, Singapore Airlines  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 127  Vistara, Singapore Airlines  28 Oct 22  Bengaluru  Rome - Fiumicino Apt
#
# ...

# %%
dt=pd.concat([a,z,n,w,s,u,o],ignore_index=True)

# %%
dt
# Out:
#                             Name        Date     Source           Destination  \
# 0               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 1               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 2               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 3               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 4               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# ..                           ...         ...        ...                   ...
# 510    Air France, Kenya Airways   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 511      Vistara, Etihad Airways   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 512         Air France, Alitalia   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 513  Vistara, Singapore Airlines   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 514  Vistara, Singapore Airlines   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
#
# ...

# %%
# Import libraries need for Modelling
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
# Dataframe columns
dt.columns
# Out:
# Index(['Name', 'Date', 'Source', 'Destination', 'Stops', 'Hours', 'Cost',
#        'Route'],
#       dtype='object')

# %%
# Seeing for the null values in the dataset
dt.isna().sum()
# Out:
# Name           0
# Date           0
# Source         0
# Destination    0
# Stops          0
# Hours          0
# Cost           0
# Route          0
# dtype: int64

# %%
# To find the data type of the dataset
for col in dt:
    print ('This column', col ,'has', dt[col].unique(),'unique elements')
    print ('*'*100)
# Out:
# This column Name has ['TAP Air Portugal' 'Air India' 'Srilankan Airlines' 'Gulf Air'
#  'Vistara, Air France' 'Etihad Airways' 'Air France' 'Qatar Airways'
#  'Emirates' 'Vistara, United Airlines' 'United Airlines' 'Lufthansa'
#  'Qatar Airways, Air Canada' 'Qatar Airways, American Airlines'
#  'Emirates, WestJet' 'Delta Air Lines' 'British Airways, Air Canada'
#  'Qatar Airways, Porter Airlines' 'Qatar Airways, WestJet' 'Air Canada'
#  'British Airways' 'Delta Air Lines, WestJet' 'American Airlines'
#  'Air France, Air Canada' 'Vistara, KLM Royal Dutch' 'Vistara, Air Canada'
#  'Vistara, United Airlines, Air Canada' 'Ethiopian Airlines' 'Swiss'
#  'Vistara, Lufthansa' 'Lufthansa, Air Canada' 'British Airways, Lufthansa'
#  'Etihad Airways, Finnair' 'Japan Airlines'
#  'Japan Airlines, American Airlines' 'KLM Royal Dutch'
#  'KLM Royal Dutch, Air France, Delta Air Lines'
#  'United Airlines, Air Canada' 'Emirates, Air Canada' 'Korean Air'
# ...

# %%
sns.heatmap(dt.isnull(), yticklabels = False, cbar = False, cmap ='viridis')
# Out:
# <AxesSubplot:>

# %%
# Getting information on the dataset
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         515 non-null    object
#  1   Date         515 non-null    object
#  2   Source       515 non-null    object
#  3   Destination  515 non-null    object
#  4   Stops        515 non-null    object
#  5   Hours        515 non-null    object
#  6   Cost         515 non-null    object
#  7   Route        515 non-null    object
# dtypes: object(8)
# memory usage: 32.3+ KB

# %%
# Getting information on the dataset
dt.describe()
# Out:
#              Name       Date     Source Destination   Stops      Hours   Cost  \
# count         515        515        515         515     515        515    515
# unique         63          7          2           4       5        263    238
# top     Lufthansa  27 Nov 22  Bengaluru     Toronto  2 stop  02 h 50 m  7,684
# freq           73        143        342         289     291         21     38
#
#              Route
# count          515
# unique         112
# top     BLR to DEL
# freq            70

# %%
# To find the data type of the dataset
dt.nunique()
# Out:
# Name            63
# Date             7
# Source           2
# Destination      4
# Stops            5
# Hours          263
# Cost           238
# Route          112
# dtype: int64

# %%
plt.subplots(figsize=(10,10))
chart =sns.countplot(dt['Date'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.show()

# %%
plt.subplots(figsize=(10,10))
chart =sns.countplot(dt['Source'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.show()

# %%
plt.subplots(figsize=(10,10))
chart =sns.countplot(dt['Destination'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.show()

# %%
plt.subplots(figsize=(10,10))
chart =sns.countplot(dt['Stops'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.show()

# %%
plt.subplots(figsize=(20,10))
chart =sns.countplot(dt['Route'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.show()

# %%
dt['Cost']=dt['Cost'].replace('₹', '')

# %%
dt['Rate']=dt['Cost'].replace('₹','')

# %%
dt
# Out:
#                             Name        Date     Source           Destination  \
# 0               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 1               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 2               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 3               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 4               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# ..                           ...         ...        ...                   ...
# 510    Air France, Kenya Airways   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 511      Vistara, Etihad Airways   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 512         Air France, Alitalia   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 513  Vistara, Singapore Airlines   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 514  Vistara, Singapore Airlines   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
#
# ...

# %%
dt.drop('Cost',axis=1,inplace=True)

# %%
dt
# Out:
#                             Name        Date     Source           Destination  \
# 0               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 1               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 2               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 3               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 4               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# ..                           ...         ...        ...                   ...
# 510    Air France, Kenya Airways   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 511      Vistara, Etihad Airways   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 512         Air France, Alitalia   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 513  Vistara, Singapore Airlines   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 514  Vistara, Singapore Airlines   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
#
# ...

# %%
dt['Price']=dt['Rate'].str.replace('₹', ' ')

# %%
dt.drop('Rate',axis=1,inplace=True)

# %%
dt
# Out:
#                             Name        Date     Source           Destination  \
# 0               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 1               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 2               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 3               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# 4               TAP Air Portugal  18 Sept 22  New Delhi               Toronto
# ..                           ...         ...        ...                   ...
# 510    Air France, Kenya Airways   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 511      Vistara, Etihad Airways   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 512         Air France, Alitalia   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 513  Vistara, Singapore Airlines   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
# 514  Vistara, Singapore Airlines   28 Oct 22  Bengaluru  Rome - Fiumicino Apt
#
# ...

# %%
dt['Price'] = dt['Price'].apply(lambda x: float(x.split()[0].replace(',', '')))

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         515 non-null    object
#  1   Date         515 non-null    object
#  2   Source       515 non-null    object
#  3   Destination  515 non-null    object
#  4   Stops        515 non-null    object
#  5   Hours        515 non-null    object
#  6   Route        515 non-null    object
#  7   Price        515 non-null    float64
# dtypes: float64(1), object(7)
# memory usage: 32.3+ KB

# %%
((dt.groupby('Name')['Price'].mean()).sort_values()).plot(kind='bar',figsize=(15,15))
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
dt['Date'].replace('21 sep 22','21 Sept 22',inplace=True)

# %%
dt['Date'].unique()
# Out:
# array(['18 Sept 22', '29 Sept 22', '29 Oct 22', '27 Nov 22', '30 Nov 22',
#        '21 Sept 22', '28 Oct 22'], dtype=object)

# %%
dt['Journey_day'] = dt['Date'].str.split(' ').str[0]
dt['Journey_month'] = dt['Date'].str.split(' ').str[1]

# %%
dt.drop('Date',axis=1,inplace=True)

# %%
dt.plot(kind='line',x='Journey_month',y='Price',figsize=(18,18))
# Out:
# <AxesSubplot:xlabel='Journey_month'>

# %%
(dt.groupby('Journey_month')['Price'].mean()).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Journey_month'>

# %%
dt['Journey_month']=dt['Journey_month'].map(lo)

# %%
dt['Journey_month'].unique()
# Out:
# array(['Sept', 'Oct', 'Nov'], dtype=object)

# %%
lo={'Sept':'9', 'Oct':'10', 'Nov':'11'}

# %%
dt
# Out:
#                             Name     Source           Destination    Stops  \
# 0               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 1               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 2               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 3               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 4               TAP Air Portugal  New Delhi               Toronto  2 Stops
# ..                           ...        ...                   ...      ...
# 510    Air France, Kenya Airways  Bengaluru  Rome - Fiumicino Apt   1 stop
# 511      Vistara, Etihad Airways  Bengaluru  Rome - Fiumicino Apt   2 stop
# 512         Air France, Alitalia  Bengaluru  Rome - Fiumicino Apt   2 stop
# 513  Vistara, Singapore Airlines  Bengaluru  Rome - Fiumicino Apt   2 stop
# 514  Vistara, Singapore Airlines  Bengaluru  Rome - Fiumicino Apt   2 stop
#
# ...

# %%
dt['Dura']=dt['Hours'].str.replace(' ', '')

# %%
#dt['Hours'].str.replace(':05',':5').str.replace("h", '*60').str.replace(' ','+').str.replace('m','1*1').apply(eval)

# %%
dt
# Out:
#                             Name     Source           Destination    Stops  \
# 0               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 1               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 2               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 3               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 4               TAP Air Portugal  New Delhi               Toronto  2 Stops
# ..                           ...        ...                   ...      ...
# 510    Air France, Kenya Airways  Bengaluru  Rome - Fiumicino Apt   1 stop
# 511      Vistara, Etihad Airways  Bengaluru  Rome - Fiumicino Apt   2 stop
# 512         Air France, Alitalia  Bengaluru  Rome - Fiumicino Apt   2 stop
# 513  Vistara, Singapore Airlines  Bengaluru  Rome - Fiumicino Apt   2 stop
# 514  Vistara, Singapore Airlines  Bengaluru  Rome - Fiumicino Apt   2 stop
#
# ...

# %%
dt['T']=dt['Dura'].str.replace('h',':').str.replace('m','')

# %%
dt
# Out:
#                             Name     Source           Destination    Stops  \
# 0               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 1               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 2               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 3               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 4               TAP Air Portugal  New Delhi               Toronto  2 Stops
# ..                           ...        ...                   ...      ...
# 510    Air France, Kenya Airways  Bengaluru  Rome - Fiumicino Apt   1 stop
# 511      Vistara, Etihad Airways  Bengaluru  Rome - Fiumicino Apt   2 stop
# 512         Air France, Alitalia  Bengaluru  Rome - Fiumicino Apt   2 stop
# 513  Vistara, Singapore Airlines  Bengaluru  Rome - Fiumicino Apt   2 stop
# 514  Vistara, Singapore Airlines  Bengaluru  Rome - Fiumicino Apt   2 stop
#
# ...

# %%
dt['Hours']=dt['T'].str.split(':').str[0]

# %%
dt['Min']=dt['T'].str.split(':').str[1]

# %%
dt
# Out:
#                             Name     Source           Destination    Stops  \
# 0               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 1               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 2               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 3               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 4               TAP Air Portugal  New Delhi               Toronto  2 Stops
# ..                           ...        ...                   ...      ...
# 510    Air France, Kenya Airways  Bengaluru  Rome - Fiumicino Apt   1 stop
# 511      Vistara, Etihad Airways  Bengaluru  Rome - Fiumicino Apt   2 stop
# 512         Air France, Alitalia  Bengaluru  Rome - Fiumicino Apt   2 stop
# 513  Vistara, Singapore Airlines  Bengaluru  Rome - Fiumicino Apt   2 stop
# 514  Vistara, Singapore Airlines  Bengaluru  Rome - Fiumicino Apt   2 stop
#
# ...

# %%
dt['Hours'].astype(int)*60
# Out:
# 0      3960
# 1      2940
# 2      2940
# 3      2940
# 4      2520
#        ...
# 510     960
# 511    1380
# 512    1020
# 513    2340
# 514    2340
# Name: Hours, Length: 515, dtype: int32

# %%
dt['Min'][513]=00

# %%
dt['Min'][514]=00

# %%
dt['Min'].unique()
# Out:
# array(['00', '05', '14', '30', '', '55', '40', '45', '10', '20', '50',
#        '15', '37', '19', '27', '23', '24', '29', '02', '33', '35', '59',
#        '04', '44', '25', '34', '52', '47', '39', '07', '57', '12', '49',
#        '54', '16', '03', '28', '32', '22', '48', '06', '09', '26', 0],
#       dtype=object)

# %%
dt['Min'].loc[np.where(dt['Min']=='')]=0

# %%
dt['Time']=dt['Hours'].astype(int)*60+dt['Min'].astype(int)

# %%
dt.drop(['Dura','Hours','T','Min'],axis=1, inplace=True)

# %%
dt
# Out:
#                             Name     Source           Destination    Stops  \
# 0               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 1               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 2               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 3               TAP Air Portugal  New Delhi               Toronto  2 Stops
# 4               TAP Air Portugal  New Delhi               Toronto  2 Stops
# ..                           ...        ...                   ...      ...
# 510    Air France, Kenya Airways  Bengaluru  Rome - Fiumicino Apt   1 stop
# 511      Vistara, Etihad Airways  Bengaluru  Rome - Fiumicino Apt   2 stop
# 512         Air France, Alitalia  Bengaluru  Rome - Fiumicino Apt   2 stop
# 513  Vistara, Singapore Airlines  Bengaluru  Rome - Fiumicino Apt   2 stop
# 514  Vistara, Singapore Airlines  Bengaluru  Rome - Fiumicino Apt   2 stop
#
# ...

# %%
((dt.groupby('Name')['Time'].mean()).sort_values()).plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
(dt.groupby('Name')['Time'].mean()).sort_values()
# Out:
# Name
# Vistara                         161.333333
# SpiceJet                        161.666667
# Akasa Air                       165.000000
# IndiGo                          184.107143
# AirAsia                         190.625000
#                                   ...
# Vistara, Singapore Airlines    2340.000000
# Emirates, Air Canada           2365.000000
# Ethiopian Airlines             2385.000000
# Srilankan Airlines             2525.000000
# TAP Air Portugal               2868.888889
# Name: Time, Length: 63, dtype: float64

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           515 non-null    object
#  1   Source         515 non-null    object
#  2   Destination    515 non-null    object
#  3   Stops          515 non-null    object
#  4   Route          515 non-null    object
#  5   Price          515 non-null    float64
#  6   Journey_day    515 non-null    object
#  7   Journey_month  515 non-null    object
#  8   Time           515 non-null    int32
# dtypes: float64(1), int32(1), object(7)
# memory usage: 34.3+ KB

# %%
dt['Stops'].unique()
# Out:
# array(['2 Stops', '1 Stop', '1 stop', 'Non st', '2 stop'], dtype=object)

# %%
dt['Stops']=dt['Stops'].map({'2 Stops':'2 Stop', '1 Stop':'1 Stop', '1 stop':'1 Stop', 'Non st':'Non-Stop', '2 stop':'2 Stop'})

# %%
dt
# Out:
#                             Name     Source           Destination   Stops  \
# 0               TAP Air Portugal  New Delhi               Toronto  2 Stop
# 1               TAP Air Portugal  New Delhi               Toronto  2 Stop
# 2               TAP Air Portugal  New Delhi               Toronto  2 Stop
# 3               TAP Air Portugal  New Delhi               Toronto  2 Stop
# 4               TAP Air Portugal  New Delhi               Toronto  2 Stop
# ..                           ...        ...                   ...     ...
# 510    Air France, Kenya Airways  Bengaluru  Rome - Fiumicino Apt  1 Stop
# 511      Vistara, Etihad Airways  Bengaluru  Rome - Fiumicino Apt  2 Stop
# 512         Air France, Alitalia  Bengaluru  Rome - Fiumicino Apt  2 Stop
# 513  Vistara, Singapore Airlines  Bengaluru  Rome - Fiumicino Apt  2 Stop
# 514  Vistara, Singapore Airlines  Bengaluru  Rome - Fiumicino Apt  2 Stop
#
#                         Route     Price Journey_day Journey_month  Time
# ...

# %%
plt.subplots(figsize=(10,10))
chart =sns.countplot(dt['Stops'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.show()

# %% [markdown]
# # Preprocessing and Model Building

# %%
#label encoder
from sklearn.preprocessing import LabelEncoder

# %%
# Assigning to a variable
le=LabelEncoder()

# %%
# Coverting all the catagorical variables to numerical in trianing dataset
dt['Name']=le.fit_transform(dt['Name'])
dt['Source']=le.fit_transform(dt['Source'])
dt['Destination']=le.fit_transform(dt['Destination'])
dt['Route']=le.fit_transform(dt['Route'])
dt['Stops']=le.fit_transform(dt['Stops'])

# %%
dt
# Out:
#      Name  Source  Destination  Stops  Route     Price Journey_day  \
# 0      48       1            3      1     97   58201.0          18
# 1      48       1            3      1     97   61020.0          18
# 2      48       1            3      1     97   61020.0          18
# 3      48       1            3      1     97   61414.0          18
# 4      48       1            3      1     97   64768.0          18
# ..    ...     ...          ...    ...    ...       ...         ...
# 510     5       0            2      0     22  255714.0          28
# 511    56       0            2      1     10  256401.0          28
# 512     3       0            2      1     23  267712.0          28
# 513    60       0            2      1     16  311355.0          28
# 514    60       0            2      1     16  311355.0          28
#
#     Journey_month  Time
# 0               9  3960
# 1               9  2945
# 2               9  2945
# 3               9  2945
# 4               9  2520
# ...

# %%
# Assignment of X and y
X=dt.drop(['Price'], axis=1)
y=dt.Price

# %%
# Standardization of the data
scalar= StandardScaler()
X_scaled=scalar.fit_transform(X)

# %%
# Applying machine learning models
# Importing machine learning libraries
# The problem is related regression the regression models are used
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error,mean_absolute_error, r2_score

# %%
for i in range(1,2000):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    li=LinearRegression()
    li.fit(x_train, y_train)
    predtrain=li.predict(x_train)
    predtest=li.predict(x_test)
    print(f"At random state, {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state, 1, the training accuracy is :-0.184004429229506
# At random state, 1, the testing accuracy is :0.49636484620467636
#
#
# At random state, 2, the training accuracy is :0.09868165605276036
# At random state, 2, the testing accuracy is :0.2770979920386363
#
#
# At random state, 3, the training accuracy is :-0.1292615653340754
# At random state, 3, the testing accuracy is :0.4230684379655758
#
#
# At random state, 4, the training accuracy is :-0.1469750544436994
# At random state, 4, the testing accuracy is :0.44838070079027825
#
#
# At random state, 5, the training accuracy is :-0.22568109292470595
# At random state, 5, the testing accuracy is :0.5311125303735689
#
#
# At random state, 6, the training accuracy is :-0.04564625945734635
# At random state, 6, the testing accuracy is :0.3879722313983419
#
#
# At random state, 7, the training accuracy is :-0.03704059903961321
# At random state, 7, the testing accuracy is :0.3775891020301325
#
#
# ...

# %% [markdown]
# NONE

# %%
for i in range(1,400):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    re=RandomForestRegressor()
    re.fit(x_train, y_train)
    predtrain=re.predict(x_train)
    predtest=re.predict(x_test)
    print(f"At random state, {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state, 1, the training accuracy is :0.930266131789451
# At random state, 1, the testing accuracy is :0.7568367288148827
#
#
# At random state, 2, the training accuracy is :0.9094545688232664
# At random state, 2, the testing accuracy is :0.6333538574794695
#
#
# At random state, 3, the training accuracy is :0.933107756555103
# At random state, 3, the testing accuracy is :0.7077814628708637
#
#
# At random state, 4, the training accuracy is :0.9382638573200353
# At random state, 4, the testing accuracy is :0.6536136996509664
#
#
# At random state, 5, the training accuracy is :0.9294972124363576
# At random state, 5, the testing accuracy is :0.6541962923427079
#
#
# At random state, 6, the training accuracy is :0.9227327755358491
# At random state, 6, the testing accuracy is :0.5958924145701064
#
#
# At random state, 7, the training accuracy is :0.9198449250487527
# At random state, 7, the testing accuracy is :0.6639251282309725
#
#
# ...

# %% [markdown]
# At random state, 256, the training accuracy is :0.9189197232257813
# At random state, 256, the testing accuracy is :0.8621895961389421

# %%
for i in range(1,400):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    xg=XGBRegressor()
    xg.fit(x_train, y_train)
    predtrain=xg.predict(x_train)
    predtest=xg.predict(x_test)
    print(f"At random state {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is :0.9846603728353472
# At random state, 1, the testing accuracy is :0.7677274959328132
#
#
# At random state 2, the training accuracy is :0.9775537520920989
# At random state, 2, the testing accuracy is :0.703364090120919
#
#
# At random state 3, the training accuracy is :0.9825447709856042
# At random state, 3, the testing accuracy is :0.7200772334895229
#
#
# At random state 4, the training accuracy is :0.9883836058850252
# At random state, 4, the testing accuracy is :0.6315336648550252
#
#
# At random state 5, the training accuracy is :0.9887416200317186
# At random state, 5, the testing accuracy is :0.6358478365727995
#
#
# At random state 6, the training accuracy is :0.9856408934103393
# At random state, 6, the testing accuracy is :0.5503898123623117
#
#
# At random state 7, the training accuracy is :0.9842546105185166
# At random state, 7, the testing accuracy is :0.6339863821960227
#
#
# ...

# %% [markdown]
# At random state 213, the training accuracy is :0.9851006393159201
# At random state, 213, the testing accuracy is :0.8670978935518964

# %%
for i in range(1,400):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    ad=AdaBoostRegressor()
    ad.fit(x_train, y_train)
    predtrain=ad.predict(x_train)
    predtest=ad.predict(x_test)
    print(f"At random state, {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state, 1, the training accuracy is :0.10608099102454693
# At random state, 1, the testing accuracy is :0.3930547937163056
#
#
# At random state, 2, the training accuracy is :0.18785345766463202
# At random state, 2, the testing accuracy is :0.37908089313222726
#
#
# At random state, 3, the training accuracy is :0.4252801478826177
# At random state, 3, the testing accuracy is :0.5570837850981857
#
#
# At random state, 4, the training accuracy is :0.619154308722431
# At random state, 4, the testing accuracy is :0.5486286620423351
#
#
# At random state, 5, the training accuracy is :0.48466804284055964
# At random state, 5, the testing accuracy is :0.549464798611041
#
#
# At random state, 6, the training accuracy is :0.5175309577802147
# At random state, 6, the testing accuracy is :0.46310370256651456
#
#
# At random state, 7, the training accuracy is :0.3425122563583526
# At random state, 7, the testing accuracy is :0.6452020539431854
#
#
# ...

# %% [raw]
# NONE

# %%
for i in range(1,400):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    kn=KNeighborsRegressor()
    kn.fit(x_train, y_train)
    predtrain=kn.predict(x_train)
    predtest=kn.predict(x_test)
    print(f"At random state {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is :0.6047311278089675
# At random state, 1, the testing accuracy is :0.7150451100431534
#
#
# At random state 2, the training accuracy is :0.6570336947387765
# At random state, 2, the testing accuracy is :0.521194438397144
#
#
# At random state 3, the training accuracy is :0.6371038007571714
# At random state, 3, the testing accuracy is :0.5750468658645398
#
#
# At random state 4, the training accuracy is :0.6039175317813147
# At random state, 4, the testing accuracy is :0.6588411608386406
#
#
# At random state 5, the training accuracy is :0.6180816650336347
# At random state, 5, the testing accuracy is :0.5417746633884482
#
#
# At random state 6, the training accuracy is :0.57891485075969
# At random state, 6, the testing accuracy is :0.6122858043470936
#
#
# At random state 7, the training accuracy is :0.6617777534185658
# At random state, 7, the testing accuracy is :0.5223630446562482
#
#
# ...

# %% [markdown]
# At random state 152, the training accuracy is :0.6451172815728641
# At random state, 152, the testing accuracy is :0.6406373444013416

# %%
for i in range(1,200):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    sr=SVR()
    sr.fit(x_train, y_train)
    predtrain=sr.predict(x_train)
    predtest=sr.predict(x_test)
    print(f"At random state {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is :-8068478.623403641
# At random state, 1, the testing accuracy is :-0.0033156339759208286
#
#
# At random state 2, the training accuracy is :-5832023.550457372
# At random state, 2, the testing accuracy is :-0.07389112249560159
#
#
# At random state 3, the training accuracy is :-7027445.523027768
# At random state, 3, the testing accuracy is :-0.08805913732102066
#
#
# At random state 4, the training accuracy is :-7287495.683565538
# At random state, 4, the testing accuracy is :-0.06485047779798658
#
#
# At random state 5, the training accuracy is :-7577628.742761899
# At random state, 5, the testing accuracy is :-0.004034188367887159
#
#
# At random state 6, the training accuracy is :-7999609.296091812
# At random state, 6, the testing accuracy is :-0.006031036879788232
#
#
# At random state 7, the training accuracy is :-7156626.248233519
# At random state, 7, the testing accuracy is :-0.01856376802774662
#
#
# ...

# %% [raw]
# NONE

# %%
for i in range(1,400):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    gr=GradientBoostingRegressor()
    gr.fit(x_train, y_train)
    predtrain=gr.predict(x_train)
    predtest=gr.predict(x_test)
    print(f"At random state, {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state, 1, the training accuracy is :0.8369798765026053
# At random state, 1, the testing accuracy is :0.7249225882351606
#
#
# At random state, 2, the training accuracy is :0.8388619105932106
# At random state, 2, the testing accuracy is :0.6879291845283011
#
#
# At random state, 3, the training accuracy is :0.852644436769887
# At random state, 3, the testing accuracy is :0.6743731092176486
#
#
# At random state, 4, the training accuracy is :0.8456440416657527
# At random state, 4, the testing accuracy is :0.6592085055592627
#
#
# At random state, 5, the training accuracy is :0.8482966623149224
# At random state, 5, the testing accuracy is :0.6666523198132595
#
#
# At random state, 6, the training accuracy is :0.832636119813427
# At random state, 6, the testing accuracy is :0.5168188680847473
#
#
# At random state, 7, the training accuracy is :0.865122336196199
# At random state, 7, the testing accuracy is :0.6885141205834691
#
#
# ...

# %% [raw]
# At random state, 107, the training accuracy is :0.8109132521855902
# At random state, 107, the testing accuracy is :0.80601231330102

# %%
x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=256)
re=RandomForestRegressor()
re.fit(x_train, y_train)
predtrain=re.predict(x_train)
predtest=re.predict(x_test)
print(f"At random state, {256}, the training accuracy is :{r2_score(predtrain,y_train)}")
print(f"At random state, {256}, the testing accuracy is :{r2_score(y_test, predtest)}")
# Out:
# At random state, 256, the training accuracy is :0.9186982017256481
# At random state, 256, the testing accuracy is :0.8667305553271245

# %%
# Calculating the MSE, RMSE and MAE for K-NN model
mse=mean_absolute_error(y_test, predtest)
rmse=np.sqrt(mse)
print('The MAE is', mean_absolute_error(y_test, predtest))
print ('The MSE is', mse, 'and RMSE is', rmse)
# Out:
# The MAE is 12570.23404381541
# The MSE is 12570.23404381541 and RMSE is 112.1170550978548

# %%
x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=213)
xg=XGBRegressor()
xg.fit(x_train, y_train)
predtrain=xg.predict(x_train)
predtest=xg.predict(x_test)
print(f"At random state {213}, the training accuracy is :{r2_score(predtrain,y_train)}")
print(f"At random state, {213}, the testing accuracy is :{r2_score(y_test, predtest)}")
# Out:
# At random state 213, the training accuracy is :0.9851006393159201
# At random state, 213, the testing accuracy is :0.8670978935518964

# %%
# Calculating the MSE, RMSE and MAE for K-NN model
mse=mean_absolute_error(y_test, predtest)
rmse=np.sqrt(mse)
print('The MAE is', mean_absolute_error(y_test, predtest))
print ('The MSE is', mse, 'and RMSE is', rmse)
# Out:
# The MAE is 16838.357445577974
# The MSE is 16838.357445577974 and RMSE is 129.7626966642493

# %%
x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=152)
kn=KNeighborsRegressor()
kn.fit(x_train, y_train)
predtrain=kn.predict(x_train)
predtest=kn.predict(x_test)
print(f"At random state {152}, the training accuracy is :{r2_score(predtrain,y_train)}")
print(f"At random state, {152}, the testing accuracy is :{r2_score(y_test, predtest)}")
# Out:
# At random state 152, the training accuracy is :0.6451172815728641
# At random state, 152, the testing accuracy is :0.6406373444013416

# %%
# Calculating the MSE, RMSE and MAE for K-NN model
mse=mean_absolute_error(y_test, predtest)
rmse=np.sqrt(mse)
print('The MAE is', mean_absolute_error(y_test, predtest))
print ('The MSE is', mse, 'and RMSE is', rmse)
# Out:
# The MAE is 26187.456310679616
# The MSE is 26187.456310679616 and RMSE is 161.8253883377995

# %%
x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=107)
gr=GradientBoostingRegressor()
gr.fit(x_train, y_train)
predtrain=gr.predict(x_train)
predtest=gr.predict(x_test)
print(f"At random state, {107}, the training accuracy is :{r2_score(predtrain,y_train)}")
print(f"At random state, {107}, the testing accuracy is :{r2_score(y_test, predtest)}")
# Out:
# At random state, 107, the training accuracy is :0.8109132521855902
# At random state, 107, the testing accuracy is :0.8061442234434835

# %%
# Calculating the MSE, RMSE and MAE for K-NN model
mse=mean_absolute_error(y_test, predtest)
rmse=np.sqrt(mse)
print('The MAE is', mean_absolute_error(y_test, predtest))
print ('The MSE is', mse, 'and RMSE is', rmse)
# Out:
# The MAE is 18851.063292273397
# The MSE is 18851.063292273397 and RMSE is 137.29917440492275

# %%
#Highest accuracy is achieved in XGBoost
x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=256)
re=RandomForestRegressor()
re.fit(x_train, y_train)
predtrain=re.predict(x_train)
predtest=re.predict(x_test)
print(f"At random state, {256}, the training accuracy is :{r2_score(predtrain,y_train)}")
print(f"At random state, {256}, the testing accuracy is :{r2_score(y_test, predtest)}")
# Calculating the MSE, RMSE and MAE for K-NN model
mse=mean_absolute_error(y_test, predtest)
rmse=np.sqrt(mse)
print('The MAE is', mean_absolute_error(y_test, predtest))
print ('The MSE is', mse, 'and RMSE is', rmse)
# Out:
# At random state, 256, the training accuracy is :0.9210784970873552
# At random state, 256, the testing accuracy is :0.869011216220525
# The MAE is 12957.08145988235
# The MSE is 12957.08145988235 and RMSE is 113.82917666346512

# %%
#Hyperparameter tuning
from sklearn.model_selection import GridSearchCV
parameters={'n_estimators' : range(2,15),
           'n_jobs': range(2,10),
           'max_depth': range(2,15)}

# %%
c=GridSearchCV(RandomForestRegressor(),param_grid=parameters)
c.fit(x_train, y_train)
print ('The best parameters are', c.best_params_)
# Out:
# The best parameters are {'max_depth': 14, 'n_estimators': 10, 'n_jobs': 5}

# %%
x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=256)
re=RandomForestRegressor(max_depth=14, n_estimators=10, n_jobs=5)
re.fit(x_train, y_train)
predtrain=re.predict(x_train)
predtest=re.predict(x_test)
print(f"At random state, {256}, the training accuracy is :{r2_score(predtrain,y_train)}")
print(f"At random state, {256}, the testing accuracy is :{r2_score(y_test, predtest)}")
# Calculating the MSE, RMSE and MAE for K-NN model
mse=mean_absolute_error(y_test, predtest)
rmse=np.sqrt(mse)
print('The MAE is', mean_absolute_error(y_test, predtest))
print ('The MSE is', mse, 'and RMSE is', rmse)
# Out:
# At random state, 256, the training accuracy is :0.9130650810656163
# At random state, 256, the testing accuracy is :0.8812360857622321
# The MAE is 12974.838366156499
# The MSE is 12974.838366156499 and RMSE is 113.90714800290849

# %% [markdown]
# # Conclusion
# The data was scrapped from the websites make my trip,yatra.com etc. From scapped data different kinds of cleaning have to be done before EDA as it comes with junk data also. It was cleaned in python and different graphs were drawn. It was seen that TAP AIR RORTUGAL was the airways having hightes amount of travelling time. The month of october most travelling occured according to the dataset. Most of them have 2 stops altest to commute. ALL NIPPON AIRWAYS is the most costliest. Most travelling occured on 27 NOV 2022. From the dataset it was seen that TORONTO was the most destination place. The XGBOOST gave the highest accuracy. At random state, 256, the training accuracy is :0.9210784970873552. At random state, 256, the testing accuracy is :0.869011216220525. The MAE is 12957.08145988235. The MSE is 12957.08145988235 and RMSE is 113.82917666346512.After hyperparameter tuning it was found to have At random state, 256, the training accuracy is :0.9130650810656163. At random state, 256, the testing accuracy is :0.8812360857622321. The MAE is 12974.838366156499. The MSE is 12974.838366156499 and RMSE is 113.90714800290849
